# %% [markdown]
# <a href="https://colab.research.google.com/github/AugustoSavi/Python-para-Ciencia-de-Dados-Formacao-Basica/blob/master/Pre_processamento_com_Sckit_Learn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns

from matplotlib import pyplot as plt
from matplotlib import rcParams
from scipy.stats.stats import pearsonr
from sklearn import preprocessing

# %matplotlib inline
rcParams['figure.figsize'] = 5, 4
sns.set_style('whitegrid')

caminho = 'https://gist.githubusercontent.com/seankross/a412dfbd88b3db70b74b/raw/5f23f993cd87c283ce766e7ac6b329ee7cc2e1d1/mtcars.csv'
carros = pd.read_csv(caminho)
carros.columns = ['nomes','mpg', 'cyl',	'disp',	'hp',	'drat','wt','qsec',	'vs','am','qtd_marchas','carb']
mpg = carros.mpg

# %%
carros[['mpg']].describe()
# Out:
#              mpg
# count  32.000000
# mean   20.090625
# std     6.026948
# min    10.400000
# 25%    15.425000
# 50%    19.200000
# 75%    22.800000
# max    33.900000

# %%
plt.plot(mpg)

# %%
mpg_mat = mpg.values.reshape(-1,1)
scaler = preprocessing.MinMaxScaler()
scaled_mpg = scaler.fit_transform(mpg_mat)

plt.plot(scaled_mpg)

# %%
scaler = preprocessing.MinMaxScaler(feature_range=(0,10))
scaled_mpg = scaler.fit_transform(mpg_mat)
plt.plot(scaled_mpg)

# %% [markdown]
# Scale()

# %%
mpg_padronizado = preprocessing.scale(mpg , axis=0, with_mean=False)
plt.plot(mpg_padronizado)

# %%
mpg_padronizado = preprocessing.scale(mpg)
plt.plot(mpg_padronizado)
